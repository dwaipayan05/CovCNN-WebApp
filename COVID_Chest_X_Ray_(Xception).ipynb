# %% [markdown]
# <a href="https://colab.research.google.com/github/dwaipayan05/CovCNN-WebApp/blob/main/COVID_Chest_X_Ray_(Xception).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Import Necessary Libraries**

# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
import keras
from keras.utils.np_utils import to_categorical
import cv2
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.layers import  Flatten, Dense, Dropout
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.applications import Xception
from keras.models import Model, Input
from keras import optimizers
from keras.optimizers import Adam
from keras.layers import Dense, GlobalAveragePooling2D
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, AveragePooling2D, GlobalAveragePooling2D
import keras_preprocessing
from keras_preprocessing import image
from keras_preprocessing.image import ImageDataGenerator
from keras import callbacks
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
# %tensorflow_version 2.x
print(tf.__version__)
print(tf.test.gpu_device_name())
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# 2.4.1
# /device:GPU:0
# Num GPUs Available:  1

# %%
# %cd /content/gdrive/"My Drive"/"COVID Chest X-Ray Analysis"
# Out:
# /content/gdrive/My Drive/COVID Chest X-Ray Analysis

# %% [markdown]
# **Fetch Dataset**

# %%
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/MyDrive/COVID Chest X-Ray Analysis"
# !kaggle datasets download -d plameneduardo/sarscov2-ctscan-dataset
# !unzip \*.zip  && rm *.zip
# Out:
# sarscov2-ctscan-dataset.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  sarscov2-ctscan-dataset.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of *.zip or
#         *.zip.zip, and cannot find sarscov2-ctscan-dataset.zip.ZIP, period.
#
# No zipfiles found.

# %% [markdown]
# **Split Into Train Data & Test Data**

# %%
disease_types=['COVID', 'non-COVID']
data_dir = '/content/gdrive/MyDrive/COVID Chest X-Ray Analysis/Dataset'
train_dir = os.path.join(data_dir)

# %%
train_data = []
for defects_id, sp in enumerate(disease_types):
    for file in os.listdir(os.path.join(train_dir, sp)):
        train_data.append(['{}/{}'.format(sp, file), defects_id, sp])      
train = pd.DataFrame(train_data, columns=['File', 'DiseaseID','Disease Type'])

# %%
IMAGE_SIZE = 64
def read_image(filepath):
    return cv2.imread(os.path.join(data_dir, filepath)) 
def resize_image(image, image_size):
    return cv2.resize(image.copy(), image_size, interpolation=cv2.INTER_AREA)

# %%
X_train = np.zeros((train.shape[0], IMAGE_SIZE, IMAGE_SIZE, 3))
for i, file in tqdm(enumerate(train['File'].values)):
    image = read_image(file)
    if image is not None:
        X_train[i] = resize_image(image, (IMAGE_SIZE, IMAGE_SIZE))
X_Train = X_train / 255.
print(X_Train.shape)
# Out:
# 2481it [14:45,  2.80it/s]
# (2481, 64, 64, 3)

# %%
Y_train = train['DiseaseID'].values
Y_train = to_categorical(Y_train, num_classes=2)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_Train, Y_train, test_size=0.2, random_state = 42)

# %% [markdown]
# **Define Xception Model Architecture**

# %%
BATCH_SIZE = 64
EPOCHS = 100
SIZE=64
N_ch=3

# %%
def build_Xception():
    xception = Xception(weights='imagenet', include_top=False)

    input = Input(shape=(SIZE, SIZE, N_ch))
    x = Conv2D(3, (3, 3), padding='same')(input)
    
    x = xception(x)
    
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # multi output
    output = Dense(2,activation = 'softmax', name='root')(x)
 

    # model
    model = Model(input,output)
    
    optimizer = Adam(lr=0.003, beta_1=0.9, beta_2=0.999, epsilon=0.1, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    model.summary()
    
    return model

# %% [markdown]
# **Train the Model**

# %%
model = build_Xception()
annealer = ReduceLROnPlateau(monitor='val_accuracy', factor=0.70, patience=5, verbose=1, min_lr=1e-4)
checkpoint = ModelCheckpoint('Xception_Model.hdf5', verbose=1, save_best_only=True)
datagen = ImageDataGenerator(rotation_range=360, 
                        width_shift_range=0.2, 
                        height_shift_range=0.2,
                        zoom_range=0.2, 
                        horizontal_flip=True, 
                        vertical_flip=True) 

datagen.fit(X_train)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 64, 64, 3)         84
# _________________________________________________________________
# xception (Functional)        (None, None, None, 2048)  20861480
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 2048)              8192
# _________________________________________________________________
# dropout (Dropout)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# root (Dense)                 (None, 2)                 514
# =================================================================
# Total params: 21,395,838
# Trainable params: 21,336,702
# Non-trainable params: 59,136
# _________________________________________________________________

# %%
history = model.fit_generator(datagen.flow(X_train, Y_train, batch_size=BATCH_SIZE),
               steps_per_epoch=X_train.shape[0] // BATCH_SIZE,
               epochs=EPOCHS,
               verbose=1,
               callbacks=[annealer, checkpoint],
               validation_data=(X_val, Y_val))
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 31/31 [==============================] - 43s 179ms/step - loss: 1.1836 - accuracy: 0.5058 - val_loss: 0.6924 - val_accuracy: 0.5312
#
# Epoch 00001: val_loss improved from inf to 0.69237, saving model to Xception_Model.hdf5
# Epoch 2/100
# 31/31 [==============================] - 4s 126ms/step - loss: 1.1277 - accuracy: 0.5158 - val_loss: 0.6927 - val_accuracy: 0.5070
#
# Epoch 00002: val_loss did not improve from 0.69237
# Epoch 3/100
# 31/31 [==============================] - 4s 127ms/step - loss: 0.9250 - accuracy: 0.5550 - val_loss: 0.6920 - val_accuracy: 0.5211
#
# Epoch 00003: val_loss improved from 0.69237 to 0.69197, saving model to Xception_Model.hdf5
# Epoch 4/100
# 31/31 [==============================] - 4s 125ms/step - loss: 0.8841 - accuracy: 0.5704 - val_loss: 0.6853 - val_accuracy: 0.5473
#
# Epoch 00004: val_loss improved from 0.69197 to 0.68532, saving model to Xception_Model.hdf5
# Epoch 5/100
# 31/31 [==============================] - 4s 125ms/step - loss: 0.7600 - accuracy: 0.6148 - val_loss: 0.6563 - val_accuracy: 0.6137
#
# Epoch 00005: val_loss improved from 0.68532 to 0.65628, saving model to Xception_Model.hdf5
# Epoch 6/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.7163 - accuracy: 0.5984 - val_loss: 0.6350 - val_accuracy: 0.6237
#
# Epoch 00006: val_loss improved from 0.65628 to 0.63496, saving model to Xception_Model.hdf5
# Epoch 7/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.6778 - accuracy: 0.6102 - val_loss: 0.6140 - val_accuracy: 0.6539
#
# Epoch 00007: val_loss improved from 0.63496 to 0.61397, saving model to Xception_Model.hdf5
# Epoch 8/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.6599 - accuracy: 0.6412 - val_loss: 0.5935 - val_accuracy: 0.6821
#
# Epoch 00008: val_loss improved from 0.61397 to 0.59346, saving model to Xception_Model.hdf5
# Epoch 9/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.6434 - accuracy: 0.6296 - val_loss: 0.5991 - val_accuracy: 0.6680
#
# Epoch 00009: val_loss did not improve from 0.59346
# Epoch 10/100
# 31/31 [==============================] - 4s 125ms/step - loss: 0.6110 - accuracy: 0.6646 - val_loss: 0.5966 - val_accuracy: 0.6620
#
# Epoch 00010: val_loss did not improve from 0.59346
# Epoch 11/100
# 31/31 [==============================] - 4s 137ms/step - loss: 0.6288 - accuracy: 0.6563 - val_loss: 0.5900 - val_accuracy: 0.6740
#
# Epoch 00011: val_loss improved from 0.59346 to 0.59002, saving model to Xception_Model.hdf5
# Epoch 12/100
# 31/31 [==============================] - 4s 122ms/step - loss: 0.5783 - accuracy: 0.6903 - val_loss: 0.5465 - val_accuracy: 0.7344
#
# Epoch 00012: val_loss improved from 0.59002 to 0.54653, saving model to Xception_Model.hdf5
# Epoch 13/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.5520 - accuracy: 0.7232 - val_loss: 0.5120 - val_accuracy: 0.7847
#
# Epoch 00013: val_loss improved from 0.54653 to 0.51195, saving model to Xception_Model.hdf5
# Epoch 14/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.5333 - accuracy: 0.7310 - val_loss: 0.5026 - val_accuracy: 0.7726
#
# Epoch 00014: val_loss improved from 0.51195 to 0.50261, saving model to Xception_Model.hdf5
# Epoch 15/100
# 31/31 [==============================] - 4s 125ms/step - loss: 0.4995 - accuracy: 0.7541 - val_loss: 0.4922 - val_accuracy: 0.7646
#
# Epoch 00015: val_loss improved from 0.50261 to 0.49216, saving model to Xception_Model.hdf5
# Epoch 16/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.4857 - accuracy: 0.7595 - val_loss: 0.4680 - val_accuracy: 0.7867
#
# Epoch 00016: val_loss improved from 0.49216 to 0.46805, saving model to Xception_Model.hdf5
# Epoch 17/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.4759 - accuracy: 0.7750 - val_loss: 0.4587 - val_accuracy: 0.7787
#
# Epoch 00017: val_loss improved from 0.46805 to 0.45867, saving model to Xception_Model.hdf5
# Epoch 18/100
# 31/31 [==============================] - 4s 125ms/step - loss: 0.4692 - accuracy: 0.7891 - val_loss: 0.4381 - val_accuracy: 0.7968
#
# Epoch 00018: val_loss improved from 0.45867 to 0.43812, saving model to Xception_Model.hdf5
# Epoch 19/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.4208 - accuracy: 0.8220 - val_loss: 0.4461 - val_accuracy: 0.7988
#
# Epoch 00019: val_loss did not improve from 0.43812
# Epoch 20/100
# 31/31 [==============================] - 4s 138ms/step - loss: 0.4289 - accuracy: 0.8061 - val_loss: 0.4686 - val_accuracy: 0.7586
#
# Epoch 00020: val_loss did not improve from 0.43812
# Epoch 21/100
# 31/31 [==============================] - 4s 125ms/step - loss: 0.3930 - accuracy: 0.8322 - val_loss: 0.4185 - val_accuracy: 0.8189
#
# Epoch 00021: val_loss improved from 0.43812 to 0.41853, saving model to Xception_Model.hdf5
# Epoch 22/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.3727 - accuracy: 0.8413 - val_loss: 0.3947 - val_accuracy: 0.8270
#
# Epoch 00022: val_loss improved from 0.41853 to 0.39474, saving model to Xception_Model.hdf5
# Epoch 23/100
# 31/31 [==============================] - 4s 125ms/step - loss: 0.3985 - accuracy: 0.8344 - val_loss: 0.3489 - val_accuracy: 0.8491
#
# Epoch 00023: val_loss improved from 0.39474 to 0.34893, saving model to Xception_Model.hdf5
# Epoch 24/100
# 31/31 [==============================] - 4s 125ms/step - loss: 0.3859 - accuracy: 0.8330 - val_loss: 0.4385 - val_accuracy: 0.8048
#
# Epoch 00024: val_loss did not improve from 0.34893
# Epoch 25/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.3846 - accuracy: 0.8447 - val_loss: 0.3859 - val_accuracy: 0.8290
#
# Epoch 00025: val_loss did not improve from 0.34893
# Epoch 26/100
# 31/31 [==============================] - 4s 143ms/step - loss: 0.3661 - accuracy: 0.8404 - val_loss: 0.3782 - val_accuracy: 0.8370
#
# Epoch 00026: val_loss did not improve from 0.34893
# Epoch 27/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.3819 - accuracy: 0.8356 - val_loss: 0.3366 - val_accuracy: 0.8632
#
# Epoch 00027: val_loss improved from 0.34893 to 0.33663, saving model to Xception_Model.hdf5
# Epoch 28/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.3410 - accuracy: 0.8665 - val_loss: 0.3346 - val_accuracy: 0.8652
#
# Epoch 00028: val_loss improved from 0.33663 to 0.33460, saving model to Xception_Model.hdf5
# Epoch 29/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.3293 - accuracy: 0.8687 - val_loss: 0.3308 - val_accuracy: 0.8632
#
# Epoch 00029: val_loss improved from 0.33460 to 0.33085, saving model to Xception_Model.hdf5
# Epoch 30/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.3416 - accuracy: 0.8651 - val_loss: 0.3623 - val_accuracy: 0.8451
#
# Epoch 00030: val_loss did not improve from 0.33085
# Epoch 31/100
# 31/31 [==============================] - 4s 130ms/step - loss: 0.3325 - accuracy: 0.8600 - val_loss: 0.3761 - val_accuracy: 0.8350
#
# Epoch 00031: val_loss did not improve from 0.33085
# Epoch 32/100
# 31/31 [==============================] - 4s 136ms/step - loss: 0.3269 - accuracy: 0.8642 - val_loss: 0.3772 - val_accuracy: 0.8290
#
# Epoch 00032: val_loss did not improve from 0.33085
# Epoch 33/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.3409 - accuracy: 0.8631 - val_loss: 0.3847 - val_accuracy: 0.8390
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.002100000018253922.
#
# Epoch 00033: val_loss did not improve from 0.33085
# Epoch 34/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.3289 - accuracy: 0.8707 - val_loss: 0.3402 - val_accuracy: 0.8531
#
# Epoch 00034: val_loss did not improve from 0.33085
# Epoch 35/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.3075 - accuracy: 0.8886 - val_loss: 0.3730 - val_accuracy: 0.8390
#
# Epoch 00035: val_loss did not improve from 0.33085
# Epoch 36/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.3096 - accuracy: 0.8762 - val_loss: 0.3787 - val_accuracy: 0.8290
#
# Epoch 00036: val_loss did not improve from 0.33085
# Epoch 37/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2987 - accuracy: 0.8848 - val_loss: 0.3318 - val_accuracy: 0.8531
#
# Epoch 00037: val_loss did not improve from 0.33085
# Epoch 38/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.3153 - accuracy: 0.8850 - val_loss: 0.3926 - val_accuracy: 0.8109
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.0014699999475851653.
#
# Epoch 00038: val_loss did not improve from 0.33085
# Epoch 39/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.3060 - accuracy: 0.8792 - val_loss: 0.3104 - val_accuracy: 0.8732
#
# Epoch 00039: val_loss improved from 0.33085 to 0.31036, saving model to Xception_Model.hdf5
# Epoch 40/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.3023 - accuracy: 0.8744 - val_loss: 0.3378 - val_accuracy: 0.8592
#
# Epoch 00040: val_loss did not improve from 0.31036
# Epoch 41/100
# 31/31 [==============================] - 4s 122ms/step - loss: 0.2959 - accuracy: 0.8800 - val_loss: 0.4047 - val_accuracy: 0.8068
#
# Epoch 00041: val_loss did not improve from 0.31036
# Epoch 42/100
# 31/31 [==============================] - 4s 140ms/step - loss: 0.2935 - accuracy: 0.8803 - val_loss: 0.3849 - val_accuracy: 0.8310
#
# Epoch 00042: val_loss did not improve from 0.31036
# Epoch 43/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2728 - accuracy: 0.9020 - val_loss: 0.5053 - val_accuracy: 0.7545
#
# Epoch 00043: val_loss did not improve from 0.31036
# Epoch 44/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2897 - accuracy: 0.8890 - val_loss: 0.3446 - val_accuracy: 0.8531
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.0010289999307133257.
#
# Epoch 00044: val_loss did not improve from 0.31036
# Epoch 45/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.3062 - accuracy: 0.8744 - val_loss: 0.3754 - val_accuracy: 0.8350
#
# Epoch 00045: val_loss did not improve from 0.31036
# Epoch 46/100
# 31/31 [==============================] - 4s 122ms/step - loss: 0.3296 - accuracy: 0.8726 - val_loss: 0.3686 - val_accuracy: 0.8330
#
# Epoch 00046: val_loss did not improve from 0.31036
# Epoch 47/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2838 - accuracy: 0.8910 - val_loss: 0.3948 - val_accuracy: 0.8229
#
# Epoch 00047: val_loss did not improve from 0.31036
# Epoch 48/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2765 - accuracy: 0.8927 - val_loss: 0.3710 - val_accuracy: 0.8370
#
# Epoch 00048: val_loss did not improve from 0.31036
# Epoch 49/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2858 - accuracy: 0.8851 - val_loss: 0.3952 - val_accuracy: 0.8149
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 0.0007202999433502554.
#
# Epoch 00049: val_loss did not improve from 0.31036
# Epoch 50/100
# 31/31 [==============================] - 4s 122ms/step - loss: 0.3019 - accuracy: 0.8801 - val_loss: 0.3556 - val_accuracy: 0.8410
#
# Epoch 00050: val_loss did not improve from 0.31036
# Epoch 51/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2659 - accuracy: 0.8914 - val_loss: 0.3369 - val_accuracy: 0.8551
#
# Epoch 00051: val_loss did not improve from 0.31036
# Epoch 52/100
# 31/31 [==============================] - 4s 122ms/step - loss: 0.2758 - accuracy: 0.9002 - val_loss: 0.3628 - val_accuracy: 0.8290
#
# Epoch 00052: val_loss did not improve from 0.31036
# Epoch 53/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.3001 - accuracy: 0.8763 - val_loss: 0.3709 - val_accuracy: 0.8330
#
# Epoch 00053: val_loss did not improve from 0.31036
# Epoch 54/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2784 - accuracy: 0.8975 - val_loss: 0.3477 - val_accuracy: 0.8511
#
# Epoch 00054: ReduceLROnPlateau reducing learning rate to 0.0005042099684942513.
#
# Epoch 00054: val_loss did not improve from 0.31036
# Epoch 55/100
# 31/31 [==============================] - 4s 122ms/step - loss: 0.2743 - accuracy: 0.8864 - val_loss: 0.3847 - val_accuracy: 0.8129
#
# Epoch 00055: val_loss did not improve from 0.31036
# Epoch 56/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2918 - accuracy: 0.8919 - val_loss: 0.3537 - val_accuracy: 0.8410
#
# Epoch 00056: val_loss did not improve from 0.31036
# Epoch 57/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2939 - accuracy: 0.8719 - val_loss: 0.3438 - val_accuracy: 0.8471
#
# Epoch 00057: val_loss did not improve from 0.31036
# Epoch 58/100
# 31/31 [==============================] - 4s 122ms/step - loss: 0.2963 - accuracy: 0.8864 - val_loss: 0.3268 - val_accuracy: 0.8592
#
# Epoch 00058: val_loss did not improve from 0.31036
# Epoch 59/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2879 - accuracy: 0.8815 - val_loss: 0.3279 - val_accuracy: 0.8632
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 0.0003529469657223671.
#
# Epoch 00059: val_loss did not improve from 0.31036
# Epoch 60/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2680 - accuracy: 0.8942 - val_loss: 0.3184 - val_accuracy: 0.8692
#
# Epoch 00060: val_loss did not improve from 0.31036
# Epoch 61/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2703 - accuracy: 0.8857 - val_loss: 0.3424 - val_accuracy: 0.8471
#
# Epoch 00061: val_loss did not improve from 0.31036
# Epoch 62/100
# 31/31 [==============================] - 4s 122ms/step - loss: 0.2860 - accuracy: 0.8820 - val_loss: 0.3410 - val_accuracy: 0.8511
#
# Epoch 00062: val_loss did not improve from 0.31036
# Epoch 63/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2772 - accuracy: 0.8966 - val_loss: 0.3307 - val_accuracy: 0.8551
#
# Epoch 00063: val_loss did not improve from 0.31036
# Epoch 64/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2742 - accuracy: 0.8974 - val_loss: 0.3146 - val_accuracy: 0.8692
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 0.0002470628678565845.
#
# Epoch 00064: val_loss did not improve from 0.31036
# Epoch 65/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2697 - accuracy: 0.8911 - val_loss: 0.3132 - val_accuracy: 0.8732
#
# Epoch 00065: val_loss did not improve from 0.31036
# Epoch 66/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2865 - accuracy: 0.8847 - val_loss: 0.3182 - val_accuracy: 0.8712
#
# Epoch 00066: val_loss did not improve from 0.31036
# Epoch 67/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2710 - accuracy: 0.8929 - val_loss: 0.3092 - val_accuracy: 0.8793
#
# Epoch 00067: val_loss improved from 0.31036 to 0.30916, saving model to Xception_Model.hdf5
# Epoch 68/100
# 31/31 [==============================] - 4s 125ms/step - loss: 0.2679 - accuracy: 0.8958 - val_loss: 0.3117 - val_accuracy: 0.8753
#
# Epoch 00068: val_loss did not improve from 0.30916
# Epoch 69/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2975 - accuracy: 0.8797 - val_loss: 0.3082 - val_accuracy: 0.8773
#
# Epoch 00069: val_loss improved from 0.30916 to 0.30823, saving model to Xception_Model.hdf5
# Epoch 70/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2695 - accuracy: 0.8856 - val_loss: 0.3085 - val_accuracy: 0.8753
#
# Epoch 00070: val_loss did not improve from 0.30823
# Epoch 71/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2706 - accuracy: 0.8877 - val_loss: 0.3100 - val_accuracy: 0.8793
#
# Epoch 00071: val_loss did not improve from 0.30823
# Epoch 72/100
# 31/31 [==============================] - 4s 137ms/step - loss: 0.2781 - accuracy: 0.8890 - val_loss: 0.3180 - val_accuracy: 0.8692
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 0.00017294401768594978.
#
# Epoch 00072: val_loss did not improve from 0.30823
# Epoch 73/100
# 31/31 [==============================] - 4s 126ms/step - loss: 0.2621 - accuracy: 0.8919 - val_loss: 0.3149 - val_accuracy: 0.8712
#
# Epoch 00073: val_loss did not improve from 0.30823
# Epoch 74/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2618 - accuracy: 0.8981 - val_loss: 0.3235 - val_accuracy: 0.8632
#
# Epoch 00074: val_loss did not improve from 0.30823
# Epoch 75/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2848 - accuracy: 0.8792 - val_loss: 0.3124 - val_accuracy: 0.8753
#
# Epoch 00075: val_loss did not improve from 0.30823
# Epoch 76/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2939 - accuracy: 0.8855 - val_loss: 0.3159 - val_accuracy: 0.8712
#
# Epoch 00076: val_loss did not improve from 0.30823
# Epoch 77/100
# 31/31 [==============================] - 4s 125ms/step - loss: 0.2569 - accuracy: 0.9018 - val_loss: 0.3192 - val_accuracy: 0.8672
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 0.00012106080830562859.
#
# Epoch 00077: val_loss did not improve from 0.30823
# Epoch 78/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2670 - accuracy: 0.8882 - val_loss: 0.3151 - val_accuracy: 0.8712
#
# Epoch 00078: val_loss did not improve from 0.30823
# Epoch 79/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2613 - accuracy: 0.8936 - val_loss: 0.3113 - val_accuracy: 0.8793
#
# Epoch 00079: val_loss did not improve from 0.30823
# Epoch 80/100
# 31/31 [==============================] - 4s 125ms/step - loss: 0.2626 - accuracy: 0.9070 - val_loss: 0.3140 - val_accuracy: 0.8712
#
# Epoch 00080: val_loss did not improve from 0.30823
# Epoch 81/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2675 - accuracy: 0.8915 - val_loss: 0.3122 - val_accuracy: 0.8753
#
# Epoch 00081: val_loss did not improve from 0.30823
# Epoch 82/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2818 - accuracy: 0.8799 - val_loss: 0.3170 - val_accuracy: 0.8692
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00082: val_loss did not improve from 0.30823
# Epoch 83/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.3287 - accuracy: 0.8723 - val_loss: 0.3153 - val_accuracy: 0.8712
#
# Epoch 00083: val_loss did not improve from 0.30823
# Epoch 84/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2429 - accuracy: 0.8970 - val_loss: 0.3214 - val_accuracy: 0.8692
#
# Epoch 00084: val_loss did not improve from 0.30823
# Epoch 85/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2792 - accuracy: 0.8889 - val_loss: 0.3277 - val_accuracy: 0.8571
#
# Epoch 00085: val_loss did not improve from 0.30823
# Epoch 86/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2974 - accuracy: 0.8784 - val_loss: 0.3254 - val_accuracy: 0.8612
#
# Epoch 00086: val_loss did not improve from 0.30823
# Epoch 87/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2608 - accuracy: 0.8969 - val_loss: 0.3217 - val_accuracy: 0.8672
#
# Epoch 00087: val_loss did not improve from 0.30823
# Epoch 88/100
# 31/31 [==============================] - 4s 122ms/step - loss: 0.2556 - accuracy: 0.9001 - val_loss: 0.3198 - val_accuracy: 0.8732
#
# Epoch 00088: val_loss did not improve from 0.30823
# Epoch 89/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2687 - accuracy: 0.8919 - val_loss: 0.3162 - val_accuracy: 0.8732
#
# Epoch 00089: val_loss did not improve from 0.30823
# Epoch 90/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2715 - accuracy: 0.8864 - val_loss: 0.3158 - val_accuracy: 0.8732
#
# Epoch 00090: val_loss did not improve from 0.30823
# Epoch 91/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2759 - accuracy: 0.8952 - val_loss: 0.3234 - val_accuracy: 0.8632
#
# Epoch 00091: val_loss did not improve from 0.30823
# Epoch 92/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2617 - accuracy: 0.8948 - val_loss: 0.3217 - val_accuracy: 0.8692
#
# Epoch 00092: val_loss did not improve from 0.30823
# Epoch 93/100
# 31/31 [==============================] - 4s 122ms/step - loss: 0.2722 - accuracy: 0.8907 - val_loss: 0.3248 - val_accuracy: 0.8612
#
# Epoch 00093: val_loss did not improve from 0.30823
# Epoch 94/100
# 31/31 [==============================] - 4s 122ms/step - loss: 0.2656 - accuracy: 0.8974 - val_loss: 0.3231 - val_accuracy: 0.8632
#
# Epoch 00094: val_loss did not improve from 0.30823
# Epoch 95/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2887 - accuracy: 0.8921 - val_loss: 0.3170 - val_accuracy: 0.8732
#
# Epoch 00095: val_loss did not improve from 0.30823
# Epoch 96/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2483 - accuracy: 0.8980 - val_loss: 0.3200 - val_accuracy: 0.8692
#
# Epoch 00096: val_loss did not improve from 0.30823
# Epoch 97/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2632 - accuracy: 0.8954 - val_loss: 0.3240 - val_accuracy: 0.8632
#
# Epoch 00097: val_loss did not improve from 0.30823
# Epoch 98/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2810 - accuracy: 0.8921 - val_loss: 0.3141 - val_accuracy: 0.8732
#
# Epoch 00098: val_loss did not improve from 0.30823
# Epoch 99/100
# 31/31 [==============================] - 4s 124ms/step - loss: 0.2742 - accuracy: 0.8946 - val_loss: 0.3167 - val_accuracy: 0.8712
#
# Epoch 00099: val_loss did not improve from 0.30823
# Epoch 100/100
# 31/31 [==============================] - 4s 123ms/step - loss: 0.2688 - accuracy: 0.9056 - val_loss: 0.3130 - val_accuracy: 0.8712
#
# Epoch 00100: val_loss did not improve from 0.30823

# %% [markdown]
# **Plot the Results**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(acc))
plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('TraiN & Val Acc VS Epochs')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
epochs = range(len(acc))
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('TraiN & Val Loss VS Epochs')
plt.legend(loc=0)
plt.figure()
plt.show()

# %%
model.load_weights("Xception_Model.hdf5")
score = model.evaluate(X_val, Y_val ,verbose=1)
print('Test Loss:', score[0])
print('Test accuracy:', score[1]*100)
# Out:
# 16/16 [==============================] - 0s 23ms/step - loss: 0.3082 - accuracy: 0.8773
# Test Loss: 0.3082253634929657
# Test accuracy: 87.7263605594635

# %%
Y_pred = model.predict(X_val)
Y_predx = np.argmax(Y_pred, axis = -1)
Y_valx = np.argmax(Y_val, axis = -1)
cf_matrix = confusion_matrix(Y_valx, Y_predx)
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot = labels, fmt = '')
plt.title("Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')
